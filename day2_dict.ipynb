# %% [markdown]
# <a href="https://colab.research.google.com/github/AnushreeKavaloor/genai-2026/blob/main/day2_dict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
My_profile = {
    "Name" : "Anushree Kavaloor",
    "Skill" : "Python basics",
    "Goal" : "GenAI engineer by 2029",
    "Study_time" : 45,
    "Day" : 2
}
#Access and print
print("Name: ",My_profile["Name"])
print("Goal: ",My_profile["Goal"])

#Updating item
My_profile["Skill"] = "Python + dict"

#Adding a new item
My_profile["City"] = "Ballari"

#Print full dict
print("My full profile: ", My_profile)
# Out:
# Name:  Anushree Kavaloor
# Goal:  GenAI engineer by 2029
# My full profile:  {'Name': 'Anushree Kavaloor', 'Skill': 'Python + dict', 'Goal': 'GenAI engineer by 2029', 'Study_time': 45, 'Day': 2, 'City': 'Ballari'}

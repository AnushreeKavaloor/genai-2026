# %% [markdown]
# <a href="https://colab.research.google.com/github/AnushreeKavaloor/genai-2026/blob/main/Day3_marks_with_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Student Marks Tracker
n = int(input(f"Enter number of students: "))
Marks = [ ]
Names = [ ]
for i in range(n):
    name = input(f"Enter name of student{i+1}: ")
    mark = int(input(f"Enter {name}'s marks: "))
    Names.append(name)
    Marks.append(mark)
average_marks = sum(Marks)/n
print(f"Class average: {average_marks:.2f}")
highest_marks = max(Marks)
for x in range(n):
     if Marks[x]==highest_marks:
         print(f"Topper is {Names[x]} with {Marks[x]} marks.")
# Out:
# Enter number of students: 3
# Enter name of student1: Anushree
# Enter Anushree's marks: 25
# Enter name of student2: Priya
# Enter Priya's marks: 35
# Enter name of student3: Chandana
# Enter Chandana's marks: 50
# Class average: 36.67
# Topper is Chandana with 50 marks.

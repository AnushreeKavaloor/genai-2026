# %% [markdown]
# <a href="https://colab.research.google.com/github/AnushreeKavaloor/genai-2026/blob/main/day1_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add_numbers(a,b):
    total = a + b
    return total
def greet_user(name):
    return f"Namaskara {name} GenAI journey started!"

#Test it

num1 = 5
num2 = 3
result = add_numbers(num1,num2)
print("Total: ", result)

your_name = input("Enter your name: ")
message = greet_user(your_name)
print(message)
# Out:
# Total:  8
# Enter your name: Anushree
# Namaskara Anushree GenAI journey started!
